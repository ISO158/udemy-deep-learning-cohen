# %% [markdown]
# ## Random sampling and sampling variability

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# create a list of numbers to compute the mean and variance of
x = [1,2,4,6,5,4,0,-4,5,-2,6,10,-9,1,3,-6]
n = len(x)

# compute the population mean
popmean = np.mean(x)

# compute a sample mean
sample = np.random.choice(x,size=5,replace=True) # eu seleciono aleatoriamente uma parte do conjunto de dados (amostra)
sampmean = np.mean(sample)

# print them
print(popmean)
print(sampmean)
# Out:
# 1.625
# 4.6

# %%
# compute lots of sample means

# number of experiments to run
nExperts = 10000

# run the experiment!
sampleMeans = np.zeros(nExperts)
for i in range(nExperts):

    # step 1: draw a sample
    sample = np.random.choice(x,size=5,replace=True)

    # step 2: compute its mean
    sampleMeans[i] = np.mean(sample)

# shows the results as a histogram
plt.hist(sampleMeans,bins=40,density=True)
plt.plot([popmean,popmean],[0,.3],'m--')
plt.ylabel('Count')
plt.xlabel('Sample mean')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
